# %%
from ast import literal_eval

with open('stats.json') as f:
    mainlist = [literal_eval(line) for line in f]
    
d = mainlist[0]
d
# Out:
# [{'control_change': 139,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRSIEVY128E0792E11.mid',
#   'lyrics': 363,
#   'note_on': 16800,
#   'pitchwheel': 34,
#   'program_change': 14,
#   'set_tempo': 1,
#   'sysex': 4,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 496,
#   'copyright': 1,
#   'end_of_track': 6,
#   'filename': 'data/lakh/lmd_subset/TRCEECS128F1474E85.mid',
#   'instrument_name': 5,
#   'key_signature': 1,
#   'midi_port': 5,
#   'note_on': 19986,
#   'pitchwheel': 4585,
#   'program_change': 21,
#   'set_tempo': 145,
#   'text': 8,
#   'time_signature': 1,
#   'track_name': 5},
#  {'control_change': 205,
#   'end_of_track': 17,
#   'filename': 'data/lakh/lmd_subset/TRXYEJV128F932F792.mid',
#   'key_signature': 1,
#   'note_on': 4242,
#   'program_change': 5,
#   'sequencer_specific': 1,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 14},
#  {'control_change': 179,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRQVKZG128F92DF7D9.mid',
#   'lyrics': 384,
#   'note_on': 24722,
#   'pitchwheel': 11,
#   'program_change': 10,
#   'set_tempo': 1,
#   'sysex': 4,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 12,
#   'copyright': 1,
#   'end_of_track': 6,
#   'filename': 'data/lakh/lmd_subset/TRXKODP128F428D5FD.mid',
#   'key_signature': 1,
#   'marker': 2,
#   'midi_port': 5,
#   'note_on': 440,
#   'program_change': 2,
#   'set_tempo': 141,
#   'text': 4,
#   'time_signature': 1,
#   'track_name': 6},
#  {'control_change': 92,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRTHPYT128F14A9E77.mid',
#   'lyrics': 272,
#   'note_on': 13706,
#   'pitchwheel': 30,
#   'program_change': 10,
#   'set_tempo': 1,
#   'sysex': 5,
#   'text': 13,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 214,
#   'end_of_track': 3,
#   'filename': 'data/lakh/lmd_subset/TRIQRTW128F931C2B2.mid',
#   'note_off': 778,
#   'note_on': 778,
#   'program_change': 4,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 2},
#  {'control_change': 42,
#   'copyright': 1,
#   'end_of_track': 19,
#   'filename': 'data/lakh/lmd_subset/TRWRREC128E07933D5.mid',
#   'key_signature': 2,
#   'marker': 10,
#   'midi_port': 18,
#   'note_on': 5846,
#   'pitchwheel': 39,
#   'program_change': 7,
#   'set_tempo': 38,
#   'sysex': 1,
#   'text': 269,
#   'time_signature': 1,
#   'track_name': 19},
#  {'control_change': 27,
#   'end_of_track': 14,
#   'filename': 'data/lakh/lmd_subset/TRHQQOW128F92FF518.mid',
#   'key_signature': 1,
#   'midi_port': 13,
#   'note_on': 4124,
#   'program_change': 9,
#   'set_tempo': 164,
#   'smpte_offset': 1,
#   'time_signature': 55,
#   'track_name': 13},
#  {'control_change': 500,
#   'end_of_track': 13,
#   'filename': 'data/lakh/lmd_subset/TRFBFMN12903CC2C8D.mid',
#   'note_off': 6474,
#   'note_on': 6474,
#   'pitchwheel': 1589,
#   'program_change': 10,
#   'set_tempo': 2,
#   'sysex': 1,
#   'text': 273,
#   'time_signature': 1,
#   'track_name': 12},
#  {'control_change': 47,
#   'end_of_track': 5,
#   'filename': 'data/lakh/lmd_subset/TRSAGQW128F4232BD7.mid',
#   'instrument_name': 4,
#   'key_signature': 1,
#   'marker': 9,
#   'note_on': 5908,
#   'program_change': 4,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'time_signature': 1,
#   'track_name': 4},
#  {'channel_prefix': 11,
#   'control_change': 15,
#   'end_of_track': 19,
#   'filename': 'data/lakh/lmd_subset/TRQTRKZ128F42BC13E.mid',
#   'key_signature': 1,
#   'note_off': 2768,
#   'note_on': 2768,
#   'program_change': 11,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 18},
#  {'control_change': 44,
#   'end_of_track': 8,
#   'filename': 'data/lakh/lmd_subset/TRGPIGL128F930AE3E.mid',
#   'key_signature': 1,
#   'midi_port': 7,
#   'note_on': 6002,
#   'program_change': 14,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 7},
#  {'control_change': 2054,
#   'end_of_track': 10,
#   'filename': 'data/lakh/lmd_subset/TRMFQYG128F4240D9E.mid',
#   'note_off': 2645,
#   'note_on': 2645,
#   'pitchwheel': 724,
#   'program_change': 16,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 10},
#  {'control_change': 9,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRAOQNR12903CBA8E2.mid',
#   'marker': 2,
#   'note_off': 4950,
#   'note_on': 4950,
#   'program_change': 5,
#   'set_tempo': 1,
#   'sysex': 3,
#   'text': 2,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 462,
#   'copyright': 1,
#   'end_of_track': 8,
#   'filename': 'data/lakh/lmd_subset/TRIUKGT12903CE68EE.mid',
#   'key_signature': 1,
#   'marker': 5,
#   'note_on': 7182,
#   'program_change': 7,
#   'set_tempo': 14,
#   'text': 34,
#   'time_signature': 1,
#   'track_name': 1},
#  {'channel_prefix': 7,
#   'control_change': 199,
#   'end_of_track': 13,
#   'filename': 'data/lakh/lmd_subset/TRRUBCD128F1484D41.mid',
#   'key_signature': 1,
#   'midi_port': 10,
#   'note_off': 1819,
#   'note_on': 1819,
#   'program_change': 7,
#   'set_tempo': 1,
#   'text': 220,
#   'time_signature': 1,
#   'track_name': 10},
#  {'control_change': 4,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRCRJGI128F9329076.mid',
#   'note_off': 993,
#   'note_on': 999,
#   'program_change': 4,
#   'set_tempo': 1,
#   'sysex': 1,
#   'text': 1,
#   'track_name': 1},
#  {'control_change': 336,
#   'end_of_track': 9,
#   'filename': 'data/lakh/lmd_subset/TRNWUXH12903D076C5.mid',
#   'marker': 12,
#   'note_off': 4873,
#   'note_on': 4873,
#   'pitchwheel': 15,
#   'program_change': 15,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 9},
#  {'control_change': 226,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRLSDIU128F42693EE.mid',
#   'note_off': 1517,
#   'note_on': 1516,
#   'pitchwheel': 24,
#   'program_change': 10,
#   'set_tempo': 1,
#   'time_signature': 1},
#  {'control_change': 36,
#   'end_of_track': 6,
#   'filename': 'data/lakh/lmd_subset/TRVQNSA128F92F58C7.mid',
#   'key_signature': 1,
#   'midi_port': 12,
#   'note_on': 1836,
#   'program_change': 10,
#   'set_tempo': 1,
#   'sysex': 6,
#   'time_signature': 1},
#  {'control_change': 8,
#   'end_of_track': 11,
#   'filename': 'data/lakh/lmd_subset/TRUSXPO128F145FB3D.mid',
#   'key_signature': 1,
#   'midi_port': 8,
#   'note_on': 8022,
#   'program_change': 8,
#   'sequencer_specific': 1,
#   'set_tempo': 1,
#   'text': 309,
#   'time_signature': 1,
#   'track_name': 8},
#  {'control_change': 397,
#   'end_of_track': 14,
#   'filename': 'data/lakh/lmd_subset/TRDNLEM128F428A318.mid',
#   'key_signature': 1,
#   'marker': 7,
#   'midi_port': 13,
#   'note_on': 8112,
#   'pitchwheel': 9,
#   'program_change': 8,
#   'set_tempo': 14,
#   'time_signature': 1,
#   'track_name': 13},
#  {'aftertouch': 31,
#   'control_change': 68,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRGMQBN128F4287676.mid',
#   'note_off': 6405,
#   'note_on': 6405,
#   'program_change': 40,
#   'set_tempo': 1,
#   'time_signature': 1},
#  {'control_change': 60,
#   'end_of_track': 12,
#   'filename': 'data/lakh/lmd_subset/TRQUXVA128F1486A25.mid',
#   'note_off': 1905,
#   'note_on': 1905,
#   'pitchwheel': 10,
#   'program_change': 10,
#   'set_tempo': 23,
#   'sysex': 2,
#   'time_signature': 2,
#   'track_name': 11},
#  {'control_change': 3196,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TREBMCU128F423A0AC.mid',
#   'marker': 3,
#   'note_off': 5125,
#   'note_on': 5125,
#   'pitchwheel': 1493,
#   'program_change': 44,
#   'set_tempo': 38,
#   'smpte_offset': 1,
#   'sysex': 18,
#   'time_signature': 27,
#   'track_name': 2},
#  {'control_change': 32,
#   'end_of_track': 9,
#   'filename': 'data/lakh/lmd_subset/TRSVFPU128F427C4A9.mid',
#   'key_signature': 8,
#   'note_off': 5112,
#   'note_on': 5112,
#   'program_change': 5,
#   'sequencer_specific': 1,
#   'set_tempo': 28,
#   'time_signature': 7,
#   'track_name': 2},
#  {'control_change': 269,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRNDYAD128F92FC555.mid',
#   'key_signature': 1,
#   'lyrics': 475,
#   'marker': 14,
#   'midi_port': 1,
#   'note_off': 5588,
#   'note_on': 5588,
#   'pitchwheel': 31,
#   'program_change': 15,
#   'set_tempo': 1,
#   'sysex': 2,
#   'time_signature': 1,
#   'track_name': 1},
#  {'end_of_track': 18,
#   'filename': 'data/lakh/lmd_subset/TRKAVKK128F42BC3F9.mid',
#   'key_signature': 1,
#   'note_off': 5285,
#   'note_on': 5285,
#   'program_change': 10,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 17},
#  {'control_change': 6006,
#   'end_of_track': 13,
#   'filename': 'data/lakh/lmd_subset/TRBNFDK12903CE4435.mid',
#   'note_off': 1514,
#   'note_on': 1514,
#   'pitchwheel': 15,
#   'program_change': 15,
#   'set_tempo': 18,
#   'text': 343,
#   'time_signature': 1,
#   'track_name': 12},
#  {'control_change': 53,
#   'end_of_track': 10,
#   'filename': 'data/lakh/lmd_subset/TRNSQCY128F428A064.mid',
#   'key_signature': 1,
#   'marker': 1,
#   'midi_port': 9,
#   'note_on': 7004,
#   'pitchwheel': 172,
#   'program_change': 9,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 8},
#  {'control_change': 442,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TROMTZO128E0784A59.mid',
#   'lyrics': 1640,
#   'note_on': 8844,
#   'pitchwheel': 670,
#   'program_change': 9,
#   'set_tempo': 1,
#   'track_name': 1},
#  {'control_change': 583,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRIZEKT128F4278359.mid',
#   'note_off': 6290,
#   'note_on': 6290,
#   'pitchwheel': 1911,
#   'program_change': 14,
#   'set_tempo': 1,
#   'sysex': 4,
#   'text': 1,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 1549,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRMHNXM128F933E6DE.mid',
#   'lyrics': 180,
#   'note_on': 4000,
#   'pitchwheel': 247,
#   'program_change': 16,
#   'set_tempo': 70,
#   'sysex': 4,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 17449,
#   'end_of_track': 17,
#   'filename': 'data/lakh/lmd_subset/TRQTFRR128F426BC4B.mid',
#   'key_signature': 1,
#   'note_on': 6230,
#   'program_change': 26,
#   'set_tempo': 627,
#   'time_signature': 2,
#   'track_name': 17},
#  {'control_change': 208,
#   'end_of_track': 4,
#   'filename': 'data/lakh/lmd_subset/TRQZIGW128F427F1B0.mid',
#   'midi_port': 1,
#   'note_off': 3210,
#   'note_on': 3210,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 30,
#   'copyright': 2,
#   'end_of_track': 16,
#   'filename': 'data/lakh/lmd_subset/TRYFUFY128F92D7F01.mid',
#   'midi_port': 15,
#   'note_on': 12184,
#   'program_change': 15,
#   'set_tempo': 1,
#   'text': 2,
#   'time_signature': 1,
#   'track_name': 16},
#  {'control_change': 72,
#   'end_of_track': 15,
#   'filename': 'data/lakh/lmd_subset/TRROYHP12903D0A329.mid',
#   'note_on': 16870,
#   'program_change': 13,
#   'set_tempo': 1,
#   'time_signature': 5,
#   'track_name': 15},
#  {'control_change': 3792,
#   'end_of_track': 17,
#   'filename': 'data/lakh/lmd_subset/TRBFPTI128F92FC318.mid',
#   'key_signature': 1,
#   'lyrics': 112,
#   'marker': 1,
#   'midi_port': 18,
#   'note_off': 876,
#   'note_on': 16068,
#   'pitchwheel': 611,
#   'program_change': 14,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'sysex': 2,
#   'text': 485,
#   'time_signature': 1,
#   'track_name': 16},
#  {'control_change': 53,
#   'end_of_track': 10,
#   'filename': 'data/lakh/lmd_subset/TRYYOWT128F42B6558.mid',
#   'note_off': 3990,
#   'note_on': 3990,
#   'pitchwheel': 6,
#   'program_change': 6,
#   'set_tempo': 3,
#   'text': 113,
#   'time_signature': 1,
#   'track_name': 10},
#  {'control_change': 384,
#   'end_of_track': 4,
#   'filename': 'data/lakh/lmd_subset/TRIUOCQ128F428D600.mid',
#   'note_off': 457,
#   'note_on': 457,
#   'pitchwheel': 2,
#   'program_change': 2,
#   'set_tempo': 128,
#   'sysex': 1,
#   'time_signature': 1,
#   'track_name': 3},
#  {'control_change': 893,
#   'end_of_track': 25,
#   'filename': 'data/lakh/lmd_subset/TRQSOWM128F931B88F.mid',
#   'key_signature': 9,
#   'midi_port': 26,
#   'note_on': 18126,
#   'program_change': 17,
#   'set_tempo': 62,
#   'sysex': 1,
#   'text': 1,
#   'time_signature': 1,
#   'track_name': 25},
#  {'control_change': 185,
#   'end_of_track': 18,
#   'filename': 'data/lakh/lmd_subset/TRRMPFB128F9349227.mid',
#   'note_off': 6782,
#   'note_on': 6782,
#   'pitchwheel': 212,
#   'program_change': 9,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 17},
#  {'control_change': 368,
#   'end_of_track': 9,
#   'filename': 'data/lakh/lmd_subset/TROTPUT128F932CFB3.mid',
#   'key_signature': 8,
#   'note_off': 5017,
#   'note_on': 5017,
#   'sequencer_specific': 1,
#   'set_tempo': 6,
#   'time_signature': 1,
#   'track_name': 8},
#  {'control_change': 539,
#   'end_of_track': 23,
#   'filename': 'data/lakh/lmd_subset/TRFWHMJ128F148E2E3.mid',
#   'key_signature': 1,
#   'marker': 1,
#   'midi_port': 22,
#   'note_on': 11732,
#   'pitchwheel': 859,
#   'program_change': 8,
#   'set_tempo': 1,
#   'sysex': 1,
#   'text': 247,
#   'time_signature': 3,
#   'track_name': 22},
#  {'control_change': 97,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRXQSFO128F92EC3B6.mid',
#   'note_off': 911,
#   'note_on': 915,
#   'program_change': 6,
#   'sequencer_specific': 1,
#   'set_tempo': 1,
#   'sysex': 1,
#   'time_signature': 1},
#  {'channel_prefix': 5,
#   'control_change': 1,
#   'end_of_track': 6,
#   'filename': 'data/lakh/lmd_subset/TRDENYV128F4295BF9.mid',
#   'note_on': 3602,
#   'set_tempo': 11,
#   'text': 5,
#   'time_signature': 1},
#  {'control_change': 230,
#   'end_of_track': 14,
#   'filename': 'data/lakh/lmd_subset/TRDIQVO128F42826D0.mid',
#   'key_signature': 1,
#   'note_on': 4682,
#   'pitchwheel': 1,
#   'program_change': 6,
#   'set_tempo': 18,
#   'time_signature': 2,
#   'track_name': 13},
#  {'channel_prefix': 4,
#   'control_change': 4,
#   'end_of_track': 6,
#   'filename': 'data/lakh/lmd_subset/TRYPYGW12903CE387C.mid',
#   'key_signature': 1,
#   'midi_port': 5,
#   'note_off': 5621,
#   'note_on': 5621,
#   'pitchwheel': 24,
#   'program_change': 4,
#   'set_tempo': 16,
#   'time_signature': 1,
#   'track_name': 4},
#  {'control_change': 874,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRRSGPS128F92EDEA0.mid',
#   'key_signature': 1,
#   'lyrics': 353,
#   'note_on': 9842,
#   'pitchwheel': 355,
#   'program_change': 15,
#   'set_tempo': 104,
#   'sysex': 1,
#   'text': 4,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 80,
#   'end_of_track': 15,
#   'filename': 'data/lakh/lmd_subset/TREJSCS128F14659AB.mid',
#   'key_signature': 1,
#   'midi_port': 14,
#   'note_on': 11072,
#   'pitchwheel': 5597,
#   'program_change': 10,
#   'set_tempo': 1,
#   'time_signature': 3,
#   'track_name': 13},
#  {'control_change': 1038,
#   'end_of_track': 17,
#   'filename': 'data/lakh/lmd_subset/TRFUMOR128F4269FFE.mid',
#   'key_signature': 1,
#   'note_on': 7116,
#   'pitchwheel': 339,
#   'program_change': 20,
#   'set_tempo': 1,
#   'sysex': 3,
#   'text': 2,
#   'time_signature': 1,
#   'track_name': 8},
#  {'control_change': 163,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRKCAQI12903CC384B.mid',
#   'note_on': 11692,
#   'pitchwheel': 90,
#   'program_change': 11,
#   'set_tempo': 1,
#   'sysex': 5,
#   'text': 1},
#  {'control_change': 111,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRTADXI128F145EBBB.mid',
#   'lyrics': 354,
#   'note_off': 3586,
#   'note_on': 3586,
#   'pitchwheel': 248,
#   'program_change': 11,
#   'set_tempo': 4,
#   'text': 2,
#   'time_signature': 1},
#  {'control_change': 32,
#   'end_of_track': 17,
#   'filename': 'data/lakh/lmd_subset/TRWPYLF12903CCD7BB.mid',
#   'key_signature': 1,
#   'marker': 1,
#   'midi_port': 16,
#   'note_on': 19760,
#   'program_change': 16,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 16},
#  {'control_change': 73,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRQNSBA12903CB0592.mid',
#   'note_on': 2080,
#   'program_change': 76,
#   'set_tempo': 1,
#   'text': 1},
#  {'control_change': 118,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRZUMHK128F9334F40.mid',
#   'lyrics': 343,
#   'note_on': 9066,
#   'pitchwheel': 363,
#   'program_change': 11,
#   'set_tempo': 1,
#   'sysex': 4,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 2468,
#   'end_of_track': 8,
#   'filename': 'data/lakh/lmd_subset/TRELUEU128F42347E0.mid',
#   'key_signature': 4,
#   'marker': 6,
#   'midi_port': 9,
#   'note_on': 10044,
#   'program_change': 2,
#   'set_tempo': 197,
#   'sysex': 1,
#   'time_signature': 2,
#   'track_name': 6},
#  {'control_change': 24,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRXCICZ128F4291042.mid',
#   'note_off': 3,
#   'note_on': 3617,
#   'program_change': 12,
#   'set_tempo': 6,
#   'track_name': 15},
#  {'control_change': 84,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRKJVDN128F4291439.mid',
#   'lyrics': 431,
#   'midi_port': 1,
#   'note_on': 10822,
#   'pitchwheel': 7,
#   'program_change': 10,
#   'set_tempo': 2,
#   'sysex': 4,
#   'text': 10,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 1046,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRSEAQB12903CC0BBC.mid',
#   'note_off': 5482,
#   'note_on': 5482,
#   'pitchwheel': 132,
#   'program_change': 12,
#   'set_tempo': 1,
#   'sysex': 4,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 72,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRHNAGL128F422B970.mid',
#   'note_off': 11013,
#   'note_on': 11013,
#   'program_change': 12,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 105,
#   'end_of_track': 26,
#   'filename': 'data/lakh/lmd_subset/TRVWIUZ128F9323426.mid',
#   'key_signature': 1,
#   'midi_port': 25,
#   'note_on': 9516,
#   'program_change': 21,
#   'set_tempo': 26,
#   'time_signature': 5,
#   'track_name': 26},
#  {'control_change': 1410,
#   'end_of_track': 8,
#   'filename': 'data/lakh/lmd_subset/TRJMXMF128F4276F6E.mid',
#   'note_off': 13189,
#   'note_on': 13189,
#   'pitchwheel': 13,
#   'program_change': 13,
#   'set_tempo': 5,
#   'time_signature': 1,
#   'track_name': 8},
#  {'control_change': 202,
#   'copyright': 1,
#   'end_of_track': 25,
#   'filename': 'data/lakh/lmd_subset/TRKPFSD12903CCE9F7.mid',
#   'key_signature': 1,
#   'lyrics': 261,
#   'note_on': 10284,
#   'pitchwheel': 67,
#   'program_change': 32,
#   'set_tempo': 1,
#   'sysex': 7,
#   'text': 7,
#   'time_signature': 1,
#   'track_name': 8},
#  {'control_change': 502,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRGCMVF128F423C6AB.mid',
#   'lyrics': 1728,
#   'note_on': 8072,
#   'pitchwheel': 309,
#   'program_change': 11,
#   'set_tempo': 1,
#   'track_name': 1},
#  {'control_change': 92,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRIBJKP128F9321212.mid',
#   'key_signature': 1,
#   'lyrics': 25,
#   'marker': 2,
#   'midi_port': 6,
#   'note_on': 8862,
#   'pitchwheel': 380,
#   'program_change': 11,
#   'set_tempo': 1,
#   'sysex': 14,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 3504,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRGFNTP12903CB81A4.mid',
#   'key_signature': 1,
#   'midi_port': 3,
#   'note_on': 5874,
#   'program_change': 14,
#   'set_tempo': 19,
#   'smpte_offset': 1,
#   'sysex': 3,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 2155,
#   'end_of_track': 11,
#   'filename': 'data/lakh/lmd_subset/TROBXRA128F424E1A7.mid',
#   'note_off': 5632,
#   'note_on': 5632,
#   'pitchwheel': 860,
#   'program_change': 17,
#   'set_tempo': 1,
#   'sysex': 92,
#   'time_signature': 1,
#   'track_name': 10},
#  {'control_change': 1126,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRYJOZK128F92F12C6.mid',
#   'key_signature': 1,
#   'lyrics': 446,
#   'midi_port': 4,
#   'note_on': 16274,
#   'pitchwheel': 297,
#   'program_change': 15,
#   'set_tempo': 3,
#   'sysex': 4,
#   'text': 3,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 476,
#   'end_of_track': 9,
#   'filename': 'data/lakh/lmd_subset/TRNXZNY128F92EB072.mid',
#   'key_signature': 1,
#   'marker': 1,
#   'midi_port': 8,
#   'note_on': 3696,
#   'pitchwheel': 1969,
#   'program_change': 12,
#   'set_tempo': 7,
#   'time_signature': 1,
#   'track_name': 8},
#  {'control_change': 7919,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRMXUAY128F4252EC2.mid',
#   'key_signature': 1,
#   'midi_port': 2,
#   'note_on': 5158,
#   'pitchwheel': 1145,
#   'program_change': 14,
#   'set_tempo': 52,
#   'sysex': 6,
#   'time_signature': 1,
#   'track_name': 2},
#  {'channel_prefix': 10,
#   'control_change': 469,
#   'end_of_track': 12,
#   'filename': 'data/lakh/lmd_subset/TRDPCBF128F92D79D3.mid',
#   'note_off': 40,
#   'note_on': 9614,
#   'pitchwheel': 144,
#   'program_change': 10,
#   'set_tempo': 18,
#   'sysex': 5,
#   'text': 13,
#   'time_signature': 1},
#  {'control_change': 539,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRGQQSQ128F934EB77.mid',
#   'note_on': 6418,
#   'pitchwheel': 14,
#   'program_change': 15,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 243,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRMYPTP128F1452130.mid',
#   'key_signature': 1,
#   'note_on': 4044,
#   'program_change': 20,
#   'set_tempo': 1,
#   'time_signature': 1},
#  {'control_change': 787,
#   'end_of_track': 12,
#   'filename': 'data/lakh/lmd_subset/TRUMFEF128F92E1E4D.mid',
#   'key_signature': 1,
#   'marker': 1,
#   'midi_port': 14,
#   'note_on': 10254,
#   'program_change': 8,
#   'set_tempo': 1,
#   'sysex': 2,
#   'time_signature': 1,
#   'track_name': 12},
#  {'control_change': 850,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRCDOIR128F146A1F3.mid',
#   'key_signature': 1,
#   'lyrics': 242,
#   'midi_port': 4,
#   'note_on': 13766,
#   'pitchwheel': 1079,
#   'program_change': 16,
#   'set_tempo': 2,
#   'sysex': 4,
#   'text': 3,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 635,
#   'copyright': 1,
#   'end_of_track': 28,
#   'filename': 'data/lakh/lmd_subset/TRLDYON12903CC509A.mid',
#   'key_signature': 1,
#   'lyrics': 276,
#   'note_on': 8902,
#   'pitchwheel': 19,
#   'program_change': 35,
#   'set_tempo': 2,
#   'sysex': 8,
#   'text': 5,
#   'time_signature': 1,
#   'track_name': 8},
#  {'control_change': 146,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRALTXO128F930843C.mid',
#   'key_signature': 1,
#   'lyrics': 137,
#   'marker': 2,
#   'midi_port': 4,
#   'note_on': 3504,
#   'program_change': 15,
#   'set_tempo': 45,
#   'smpte_offset': 1,
#   'sysex': 3,
#   'text': 1,
#   'time_signature': 7,
#   'track_name': 1},
#  {'channel_prefix': 5,
#   'control_change': 125,
#   'copyright': 1,
#   'end_of_track': 6,
#   'filename': 'data/lakh/lmd_subset/TRFOUAP128E078C216.mid',
#   'key_signature': 1,
#   'midi_port': 5,
#   'note_off': 2163,
#   'note_on': 2163,
#   'pitchwheel': 6,
#   'program_change': 6,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'sysex': 7,
#   'text': 1,
#   'time_signature': 1,
#   'track_name': 6},
#  {'control_change': 2028,
#   'end_of_track': 21,
#   'filename': 'data/lakh/lmd_subset/TRNBXRS128F4222D21.mid',
#   'note_off': 11286,
#   'note_on': 11286,
#   'pitchwheel': 658,
#   'program_change': 12,
#   'set_tempo': 1,
#   'sysex': 5,
#   'text': 20,
#   'time_signature': 1,
#   'track_name': 20},
#  {'control_change': 829,
#   'end_of_track': 11,
#   'filename': 'data/lakh/lmd_subset/TREDSZN128F4219D78.mid',
#   'note_off': 4715,
#   'note_on': 4715,
#   'program_change': 10,
#   'set_tempo': 10,
#   'time_signature': 20,
#   'track_name': 10},
#  {'control_change': 160,
#   'end_of_track': 6,
#   'filename': 'data/lakh/lmd_subset/TRYAQIG12903CBB77C.mid',
#   'note_off': 1315,
#   'note_on': 1315,
#   'pitchwheel': 35,
#   'program_change': 24,
#   'set_tempo': 1,
#   'track_name': 5},
#  {'control_change': 418,
#   'end_of_track': 4,
#   'filename': 'data/lakh/lmd_subset/TRCEPKN128F4256048.mid',
#   'midi_port': 1,
#   'note_off': 3888,
#   'note_on': 3888,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 439,
#   'end_of_track': 11,
#   'filename': 'data/lakh/lmd_subset/TRFYAJR128F1480A75.mid',
#   'key_signature': 1,
#   'midi_port': 10,
#   'note_on': 4088,
#   'pitchwheel': 3296,
#   'program_change': 9,
#   'set_tempo': 7,
#   'smpte_offset': 1,
#   'time_signature': 1,
#   'track_name': 10},
#  {'control_change': 6845,
#   'end_of_track': 13,
#   'filename': 'data/lakh/lmd_subset/TRTOAMG128F92E0A6A.mid',
#   'key_signature': 12,
#   'note_off': 2272,
#   'note_on': 2272,
#   'program_change': 28,
#   'set_tempo': 9,
#   'time_signature': 1,
#   'track_name': 13},
#  {'control_change': 726,
#   'copyright': 1,
#   'end_of_track': 8,
#   'filename': 'data/lakh/lmd_subset/TRHXUFW12903CDEE0B.mid',
#   'key_signature': 1,
#   'midi_port': 7,
#   'note_on': 10106,
#   'program_change': 7,
#   'set_tempo': 1,
#   'text': 2,
#   'time_signature': 1,
#   'track_name': 9},
#  {'control_change': 867,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRREPDE128F92F15B7.mid',
#   'note_off': 2713,
#   'note_on': 11809,
#   'pitchwheel': 655,
#   'program_change': 10,
#   'set_tempo': 8,
#   'sysex': 5,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 8,
#   'end_of_track': 6,
#   'filename': 'data/lakh/lmd_subset/TRXBHWC128F426E437.mid',
#   'note_off': 4787,
#   'note_on': 4787,
#   'program_change': 4,
#   'set_tempo': 1,
#   'sysex': 1,
#   'time_signature': 1,
#   'track_name': 5},
#  {'control_change': 244,
#   'end_of_track': 11,
#   'filename': 'data/lakh/lmd_subset/TRWVTBY128F92C60E1.mid',
#   'key_signature': 1,
#   'midi_port': 8,
#   'note_on': 5830,
#   'program_change': 8,
#   'set_tempo': 1,
#   'text': 343,
#   'time_signature': 1,
#   'track_name': 10},
#  {'control_change': 8,
#   'end_of_track': 14,
#   'filename': 'data/lakh/lmd_subset/TRQTTJS128F9316BAB.mid',
#   'note_off': 6908,
#   'note_on': 6908,
#   'program_change': 8,
#   'set_tempo': 1,
#   'text': 13,
#   'time_signature': 1},
#  {'control_change': 1351,
#   'copyright': 1,
#   'end_of_track': 14,
#   'filename': 'data/lakh/lmd_subset/TRLDCZE128F9334CDF.mid',
#   'key_signature': 1,
#   'lyrics': 307,
#   'note_off': 2901,
#   'note_on': 2901,
#   'pitchwheel': 81,
#   'program_change': 11,
#   'set_tempo': 2,
#   'sysex': 1,
#   'text': 1,
#   'time_signature': 2,
#   'track_name': 1},
#  {'control_change': 408,
#   'end_of_track': 11,
#   'filename': 'data/lakh/lmd_subset/TRDFSUA128F1495990.mid',
#   'key_signature': 1,
#   'marker': 1,
#   'midi_port': 13,
#   'note_on': 6032,
#   'pitchwheel': 2960,
#   'program_change': 6,
#   'set_tempo': 1,
#   'sysex': 2,
#   'time_signature': 1,
#   'track_name': 11},
#  {'control_change': 230,
#   'end_of_track': 7,
#   'filename': 'data/lakh/lmd_subset/TRWOFTG128F4290996.mid',
#   'marker': 7,
#   'note_off': 7111,
#   'note_on': 7111,
#   'pitchwheel': 11,
#   'program_change': 23,
#   'set_tempo': 11,
#   'time_signature': 1,
#   'track_name': 7},
#  {'control_change': 3065,
#   'end_of_track': 19,
#   'filename': 'data/lakh/lmd_subset/TRASUDV128F42B86FB.mid',
#   'key_signature': 1,
#   'marker': 1,
#   'midi_port': 20,
#   'note_on': 15836,
#   'pitchwheel': 9518,
#   'program_change': 17,
#   'set_tempo': 1,
#   'sysex': 1,
#   'time_signature': 1,
#   'track_name': 10},
#  {'control_change': 324,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRMKPEI128F930797A.mid',
#   'instrument_name': 1,
#   'key_signature': 1,
#   'note_off': 3139,
#   'note_on': 3139,
#   'pitchwheel': 80,
#   'program_change': 9,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'sysex': 3,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 1962,
#   'end_of_track': 17,
#   'filename': 'data/lakh/lmd_subset/TRFWAOI12903CC4C88.mid',
#   'note_on': 13706,
#   'pitchwheel': 53,
#   'program_change': 16,
#   'set_tempo': 2,
#   'sysex': 3,
#   'text': 17,
#   'time_signature': 1},
#  {'control_change': 7,
#   'end_of_track': 11,
#   'filename': 'data/lakh/lmd_subset/TRFINAP128F93269EF.mid',
#   'note_off': 4710,
#   'note_on': 4710,
#   'program_change': 7,
#   'set_tempo': 1,
#   'sysex': 1,
#   'time_signature': 1,
#   'track_name': 10},
#  {'control_change': 17791,
#   'end_of_track': 11,
#   'filename': 'data/lakh/lmd_subset/TRKIZHD128F4256CC0.mid',
#   'note_off': 3738,
#   'note_on': 3738,
#   'pitchwheel': 2642,
#   'program_change': 37,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 11},
#  {'control_change': 396,
#   'end_of_track': 10,
#   'filename': 'data/lakh/lmd_subset/TRAYIFV128F934B689.mid',
#   'note_off': 6119,
#   'note_on': 6119,
#   'pitchwheel': 175,
#   'program_change': 6,
#   'sequencer_specific': 2,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 9},
#  {'control_change': 1,
#   'end_of_track': 10,
#   'filename': 'data/lakh/lmd_subset/TRZMHGG128F145A6B4.mid',
#   'key_signature': 1,
#   'midi_port': 9,
#   'note_off': 1409,
#   'note_on': 1409,
#   'program_change': 9,
#   'set_tempo': 1,
#   'text': 23,
#   'time_signature': 1,
#   'track_name': 9},
#  {'control_change': 1514,
#   'end_of_track': 8,
#   'filename': 'data/lakh/lmd_subset/TRODYKJ128F92E96DB.mid',
#   'note_off': 1829,
#   'note_on': 1829,
#   'pitchwheel': 2610,
#   'program_change': 7,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 7},
#  {'control_change': 160,
#   'end_of_track': 12,
#   'filename': 'data/lakh/lmd_subset/TRTRIPG128F92CF96F.mid',
#   'note_off': 275,
#   'note_on': 275,
#   'pitchwheel': 35,
#   'program_change': 6,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 10},
#  {'control_change': 13,
#   'end_of_track': 33,
#   'filename': 'data/lakh/lmd_subset/TRRVCED128F426E38E.mid',
#   'key_signature': 1,
#   'marker': 1,
#   'midi_port': 32,
#   'note_on': 14278,
#   'program_change': 25,
#   'set_tempo': 49,
#   'time_signature': 1,
#   'track_name': 32},
#  {'aftertouch': 30,
#   'control_change': 184,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRLMULZ128F428C3C7.mid',
#   'note_off': 6876,
#   'note_on': 6876,
#   'pitchwheel': 72,
#   'program_change': 26,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 81,
#   'end_of_track': 6,
#   'filename': 'data/lakh/lmd_subset/TROMMAA128EF34318C.mid',
#   'note_off': 4738,
#   'note_on': 4738,
#   'pitchwheel': 9,
#   'program_change': 13,
#   'set_tempo': 2,
#   'time_signature': 8,
#   'track_name': 6},
#  {'control_change': 637,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRMGOGQ128F92F7998.mid',
#   'lyrics': 333,
#   'note_on': 2161,
#   'pitchwheel': 7,
#   'program_change': 7,
#   'set_tempo': 48,
#   'sysex': 5,
#   'text': 2},
#  {'control_change': 72,
#   'end_of_track': 3,
#   'filename': 'data/lakh/lmd_subset/TRBITMM128F428624A.mid',
#   'note_off': 518,
#   'note_on': 518,
#   'set_tempo': 1,
#   'sysex': 1,
#   'time_signature': 1,
#   'track_name': 2},
#  {'control_change': 1732,
#   'end_of_track': 12,
#   'filename': 'data/lakh/lmd_subset/TRBXBFO128E078EB3F.mid',
#   'instrument_name': 11,
#   'marker': 14,
#   'note_off': 11125,
#   'note_on': 11125,
#   'pitchwheel': 9467,
#   'program_change': 10,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'sysex': 1,
#   'time_signature': 1,
#   'track_name': 12},
#  {'control_change': 218,
#   'end_of_track': 9,
#   'filename': 'data/lakh/lmd_subset/TRIDQPS12903CF07A1.mid',
#   'marker': 13,
#   'note_off': 2365,
#   'note_on': 2365,
#   'pitchwheel': 70,
#   'program_change': 9,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 9},
#  {'control_change': 2284,
#   'end_of_track': 30,
#   'filename': 'data/lakh/lmd_subset/TRFTQWV128F92C3270.mid',
#   'note_off': 5836,
#   'note_on': 5836,
#   'pitchwheel': 138,
#   'program_change': 15,
#   'set_tempo': 1,
#   'sysex': 2,
#   'text': 30,
#   'time_signature': 1,
#   'track_name': 29},
#  {'control_change': 830,
#   'end_of_track': 11,
#   'filename': 'data/lakh/lmd_subset/TRMWYPB128F930966D.mid',
#   'lyrics': 342,
#   'note_off': 4836,
#   'note_on': 4836,
#   'pitchwheel': 298,
#   'program_change': 26,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 10},
#  {'control_change': 1315,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TREEWGN128F92CC942.mid',
#   'note_on': 13372,
#   'pitchwheel': 352,
#   'program_change': 12,
#   'set_tempo': 1,
#   'sysex': 5,
#   'text': 1},
#  {'control_change': 3066,
#   'end_of_track': 15,
#   'filename': 'data/lakh/lmd_subset/TRJXZXD128F4228BEC.mid',
#   'note_off': 3133,
#   'note_on': 3133,
#   'pitchwheel': 849,
#   'program_change': 12,
#   'set_tempo': 3,
#   'sysex': 3,
#   'time_signature': 1,
#   'track_name': 14},
#  {'control_change': 255,
#   'end_of_track': 20,
#   'filename': 'data/lakh/lmd_subset/TRJGJXS12903CD63F5.mid',
#   'key_signature': 1,
#   'note_on': 1324,
#   'program_change': 25,
#   'set_tempo': 3,
#   'sysex': 2,
#   'text': 11,
#   'time_signature': 1,
#   'track_name': 20},
#  {'control_change': 520,
#   'end_of_track': 17,
#   'filename': 'data/lakh/lmd_subset/TRNJIFX128F42AE50D.mid',
#   'key_signature': 1,
#   'marker': 3,
#   'midi_port': 18,
#   'note_on': 12956,
#   'pitchwheel': 162,
#   'program_change': 9,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'sysex': 3,
#   'time_signature': 1},
#  {'control_change': 806,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRERQQP128F14AF515.mid',
#   'key_signature': 1,
#   'marker': 117,
#   'midi_port': 21,
#   'note_off': 444,
#   'note_on': 15082,
#   'pitchwheel': 288,
#   'program_change': 18,
#   'set_tempo': 2,
#   'smpte_offset': 1,
#   'sysex': 4,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 69,
#   'copyright': 1,
#   'end_of_track': 13,
#   'filename': 'data/lakh/lmd_subset/TRESUPH12903CBBD5F.mid',
#   'key_signature': 1,
#   'midi_port': 12,
#   'note_on': 5794,
#   'pitchwheel': 672,
#   'program_change': 8,
#   'sequencer_specific': 12,
#   'set_tempo': 5,
#   'smpte_offset': 1,
#   'sysex': 4,
#   'time_signature': 3,
#   'track_name': 13},
#  {'control_change': 203,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRNWGJC128E07994B5.mid',
#   'note_off': 7523,
#   'note_on': 7523,
#   'pitchwheel': 177,
#   'program_change': 12,
#   'set_tempo': 1,
#   'sysex': 4,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 47,
#   'copyright': 1,
#   'end_of_track': 8,
#   'filename': 'data/lakh/lmd_subset/TRRBCBD128F42954E0.mid',
#   'key_signature': 1,
#   'midi_port': 7,
#   'note_on': 15040,
#   'program_change': 6,
#   'set_tempo': 1,
#   'text': 2,
#   'time_signature': 1,
#   'track_name': 9},
#  {'control_change': 85,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRVWUKV128F9325DF4.mid',
#   'key_signature': 1,
#   'lyrics': 334,
#   'note_off': 6344,
#   'note_on': 6344,
#   'pitchwheel': 2247,
#   'program_change': 13,
#   'set_tempo': 3,
#   'sysex': 1,
#   'text': 1,
#   'time_signature': 2,
#   'track_name': 1},
#  {'control_change': 42,
#   'end_of_track': 2,
#   'filename': 'data/lakh/lmd_subset/TRQYMWE128F931251C.mid',
#   'note_off': 426,
#   'note_on': 426,
#   'pitchwheel': 2,
#   'program_change': 2,
#   'set_tempo': 19,
#   'time_signature': 1,
#   'track_name': 2},
#  {'control_change': 267,
#   'end_of_track': 14,
#   'filename': 'data/lakh/lmd_subset/TRZJFFH128F14647FC.mid',
#   'note_off': 1480,
#   'note_on': 1480,
#   'pitchwheel': 82,
#   'program_change': 5,
#   'set_tempo': 311,
#   'time_signature': 1,
#   'track_name': 13},
#  {'control_change': 100,
#   'end_of_track': 16,
#   'filename': 'data/lakh/lmd_subset/TRTBVMO128F9303E0F.mid',
#   'note_off': 7187,
#   'note_on': 7187,
#   'program_change': 10,
#   'set_tempo': 1,
#   'sysex': 2,
#   'time_signature': 1,
#   'track_name': 15},
#  {'control_change': 90,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRSWBTU128F4288E52.mid',
#   'key_signature': 1,
#   'marker': 1,
#   'note_on': 7778,
#   'pitchwheel': 857,
#   'program_change': 11,
#   'set_tempo': 1,
#   'time_signature': 1},
#  {'control_change': 317,
#   'copyright': 1,
#   'end_of_track': 12,
#   'filename': 'data/lakh/lmd_subset/TRGOCEK128EF367FD3.mid',
#   'key_signature': 1,
#   'midi_port': 11,
#   'note_on': 10384,
#   'program_change': 7,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 11},
#  {'control_change': 31,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRCMAED12903CE0094.mid',
#   'key_signature': 1,
#   'lyrics': 386,
#   'marker': 2,
#   'midi_port': 2,
#   'note_on': 14410,
#   'program_change': 8,
#   'set_tempo': 1,
#   'text': 2,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 36,
#   'end_of_track': 12,
#   'filename': 'data/lakh/lmd_subset/TRPNWXT128F9311401.mid',
#   'key_signature': 1,
#   'midi_port': 11,
#   'note_on': 5388,
#   'program_change': 10,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'text': 6,
#   'time_signature': 1,
#   'track_name': 5},
#  {'control_change': 174,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRDADUJ128F1493BE8.mid',
#   'key_signature': 1,
#   'lyrics': 317,
#   'note_on': 11748,
#   'pitchwheel': 1051,
#   'program_change': 10,
#   'set_tempo': 1,
#   'sysex': 1,
#   'text': 4,
#   'time_signature': 7,
#   'track_name': 1},
#  {'control_change': 871,
#   'copyright': 1,
#   'end_of_track': 17,
#   'filename': 'data/lakh/lmd_subset/TRHQXHW128F425B767.mid',
#   'key_signature': 1,
#   'note_off': 4827,
#   'note_on': 4827,
#   'pitchwheel': 644,
#   'program_change': 10,
#   'set_tempo': 1,
#   'text': 1,
#   'time_signature': 1,
#   'track_name': 17},
#  {'control_change': 48,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRDWHDE128F9308934.mid',
#   'key_signature': 1,
#   'lyrics': 321,
#   'midi_port': 23,
#   'note_off': 76,
#   'note_on': 6286,
#   'program_change': 10,
#   'set_tempo': 1,
#   'sysex': 4,
#   'time_signature': 1},
#  {'control_change': 407,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRRXFEI128F92D054B.mid',
#   'lyrics': 797,
#   'note_on': 18118,
#   'pitchwheel': 219,
#   'program_change': 14,
#   'set_tempo': 2,
#   'sysex': 4,
#   'text': 1},
#  {'control_change': 10,
#   'copyright': 1,
#   'end_of_track': 7,
#   'filename': 'data/lakh/lmd_subset/TRNRZIT128F4246E00.mid',
#   'key_signature': 1,
#   'marker': 8,
#   'note_on': 9820,
#   'pitchwheel': 6232,
#   'program_change': 4,
#   'set_tempo': 3,
#   'text': 1,
#   'time_signature': 1,
#   'track_name': 7},
#  {'control_change': 34,
#   'copyright': 1,
#   'end_of_track': 16,
#   'filename': 'data/lakh/lmd_subset/TRVZOGL128F423B1D6.mid',
#   'key_signature': 1,
#   'marker': 1,
#   'midi_port': 13,
#   'note_on': 5298,
#   'program_change': 7,
#   'set_tempo': 1,
#   'text': 568,
#   'time_signature': 1,
#   'track_name': 7},
#  {'control_change': 1469,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRXLGDL12903C9B88B.mid',
#   'key_signature': 1,
#   'lyrics': 746,
#   'note_on': 35500,
#   'pitchwheel': 1044,
#   'program_change': 8,
#   'set_tempo': 1,
#   'sysex': 1,
#   'time_signature': 1,
#   'track_name': 1},
#  {'aftertouch': 7140,
#   'control_change': 427,
#   'end_of_track': 11,
#   'filename': 'data/lakh/lmd_subset/TROSRCZ128F4215BEB.mid',
#   'note_off': 1742,
#   'note_on': 1742,
#   'pitchwheel': 69,
#   'program_change': 9,
#   'set_tempo': 1,
#   'text': 285,
#   'time_signature': 3,
#   'track_name': 10},
#  {'control_change': 35,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRNGVVH128F4257211.mid',
#   'key_signature': 1,
#   'note_off': 2889,
#   'note_on': 2889,
#   'program_change': 10,
#   'set_tempo': 1,
#   'text': 19,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 599,
#   'end_of_track': 30,
#   'filename': 'data/lakh/lmd_subset/TRTYQGB128F147B5AB.mid',
#   'key_signature': 1,
#   'midi_port': 29,
#   'note_on': 7382,
#   'program_change': 11,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 30},
#  {'channel_prefix': 7,
#   'control_change': 35,
#   'end_of_track': 14,
#   'filename': 'data/lakh/lmd_subset/TRGPHXE12903CEB155.mid',
#   'key_signature': 1,
#   'midi_port': 13,
#   'note_off': 4393,
#   'note_on': 4393,
#   'program_change': 7,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'time_signature': 1,
#   'track_name': 13},
#  {'control_change': 396,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRKYFKI128E078E83A.mid',
#   'key_signature': 1,
#   'lyrics': 569,
#   'marker': 23,
#   'note_on': 12750,
#   'pitchwheel': 476,
#   'program_change': 6,
#   'set_tempo': 1,
#   'time_signature': 1},
#  {'control_change': 3,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRJFQCA128F9315D02.mid',
#   'note_on': 5248,
#   'program_change': 8,
#   'set_tempo': 1,
#   'text': 1},
#  {'control_change': 1081,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRONGWF128F93499A9.mid',
#   'instrument_name': 1,
#   'key_signature': 1,
#   'lyrics': 451,
#   'note_on': 13386,
#   'pitchwheel': 751,
#   'program_change': 11,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'sysex': 13,
#   'text': 1,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 46,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRJWHST128F4289AB8.mid',
#   'key_signature': 1,
#   'lyrics': 246,
#   'note_on': 5660,
#   'pitchwheel': 10,
#   'program_change': 5,
#   'sequencer_specific': 1,
#   'set_tempo': 1,
#   'text': 4,
#   'time_signature': 1},
#  {'control_change': 378,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRQGVKO128F422B162.mid',
#   'key_signature': 1,
#   'lyrics': 316,
#   'note_on': 7646,
#   'program_change': 9,
#   'set_tempo': 21,
#   'text': 15,
#   'time_signature': 1},
#  {'control_change': 541,
#   'end_of_track': 12,
#   'filename': 'data/lakh/lmd_subset/TRKSLSS128F145A847.mid',
#   'key_signature': 1,
#   'midi_port': 108,
#   'note_on': 7508,
#   'pitchwheel': 99,
#   'program_change': 9,
#   'set_tempo': 1,
#   'sysex': 264,
#   'text': 280,
#   'time_signature': 1,
#   'track_name': 3},
#  {'control_change': 784,
#   'end_of_track': 11,
#   'filename': 'data/lakh/lmd_subset/TRLTMMW128F148D809.mid',
#   'key_signature': 1,
#   'marker': 6,
#   'midi_port': 10,
#   'note_on': 5358,
#   'pitchwheel': 434,
#   'program_change': 13,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 10},
#  {'control_change': 24,
#   'end_of_track': 25,
#   'filename': 'data/lakh/lmd_subset/TRUPAMN128F148BFCA.mid',
#   'key_signature': 1,
#   'midi_port': 54,
#   'note_on': 8766,
#   'program_change': 21,
#   'set_tempo': 1,
#   'sysex': 15,
#   'time_signature': 1,
#   'track_name': 23},
#  {'control_change': 213,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRXDLOO128F9305E7F.mid',
#   'note_off': 749,
#   'note_on': 990,
#   'program_change': 4,
#   'set_tempo': 1,
#   'sysex': 1},
#  {'channel_prefix': 6,
#   'control_change': 45,
#   'end_of_track': 9,
#   'filename': 'data/lakh/lmd_subset/TRDKHFB128F9333A85.mid',
#   'key_signature': 7,
#   'note_off': 1543,
#   'note_on': 1543,
#   'pitchwheel': 21,
#   'program_change': 6,
#   'sequencer_specific': 422,
#   'set_tempo': 1,
#   'text': 349,
#   'time_signature': 7,
#   'track_name': 8},
#  {'control_change': 756,
#   'end_of_track': 17,
#   'filename': 'data/lakh/lmd_subset/TRJCXTP128F4265787.mid',
#   'note_off': 3551,
#   'note_on': 3551,
#   'pitchwheel': 56,
#   'program_change': 31,
#   'set_tempo': 1,
#   'time_signature': 5,
#   'track_name': 16},
#  {'control_change': 2128,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRZCNCT12903CD0780.mid',
#   'key_signature': 1,
#   'note_off': 775,
#   'note_on': 17333,
#   'pitchwheel': 694,
#   'program_change': 103,
#   'set_tempo': 3,
#   'sysex': 1,
#   'time_signature': 3},
#  {'control_change': 2133,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRFQPWB128F9316B26.mid',
#   'lyrics': 382,
#   'note_on': 12308,
#   'pitchwheel': 267,
#   'program_change': 22,
#   'set_tempo': 1,
#   'sysex': 4,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 320,
#   'end_of_track': 14,
#   'filename': 'data/lakh/lmd_subset/TRUUOUW12903CB2961.mid',
#   'note_off': 4674,
#   'note_on': 4674,
#   'pitchwheel': 116,
#   'program_change': 21,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 14},
#  {'control_change': 640,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRLCDFA12903CD4360.mid',
#   'lyrics': 452,
#   'note_on': 30714,
#   'pitchwheel': 957,
#   'program_change': 10,
#   'set_tempo': 1,
#   'sysex': 4,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 212,
#   'end_of_track': 15,
#   'filename': 'data/lakh/lmd_subset/TRTPRTU12903CBEF22.mid',
#   'key_signature': 1,
#   'note_on': 11320,
#   'program_change': 10,
#   'set_tempo': 1,
#   'text': 586,
#   'time_signature': 1,
#   'track_name': 15},
#  {'control_change': 5,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRPUZQF128F425565C.mid',
#   'note_off': 768,
#   'note_on': 768,
#   'program_change': 5,
#   'set_tempo': 1,
#   'sysex': 1,
#   'time_signature': 1},
#  {'control_change': 236,
#   'end_of_track': 12,
#   'filename': 'data/lakh/lmd_subset/TRKBTID128F92E1D5C.mid',
#   'note_off': 2937,
#   'note_on': 2937,
#   'pitchwheel': 24,
#   'program_change': 7,
#   'set_tempo': 1,
#   'text': 282,
#   'time_signature': 1,
#   'track_name': 11},
#  {'control_change': 957,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRUWDWJ128F42721FC.mid',
#   'key_signature': 16,
#   'marker': 30,
#   'note_on': 20598,
#   'pitchwheel': 2651,
#   'program_change': 15,
#   'set_tempo': 159,
#   'text': 1,
#   'time_signature': 34,
#   'track_name': 2},
#  {'control_change': 1,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TREHYZQ12903D0CB95.mid',
#   'key_signature': 1,
#   'lyrics': 574,
#   'note_on': 12056,
#   'program_change': 6,
#   'set_tempo': 1,
#   'text': 1,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 1501,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRAPDIO128F933C680.mid',
#   'key_signature': 1,
#   'lyrics': 349,
#   'note_off': 4128,
#   'note_on': 4128,
#   'pitchwheel': 169,
#   'program_change': 6,
#   'set_tempo': 1,
#   'sysex': 1,
#   'time_signature': 2,
#   'track_name': 1},
#  {'control_change': 557,
#   'end_of_track': 3,
#   'filename': 'data/lakh/lmd_subset/TRYFRTK128F9339372.mid',
#   'instrument_name': 2,
#   'key_signature': 1,
#   'note_on': 4836,
#   'set_tempo': 1,
#   'track_name': 3},
#  {'aftertouch': 25,
#   'channel_prefix': 6,
#   'control_change': 17,
#   'end_of_track': 7,
#   'filename': 'data/lakh/lmd_subset/TRJEREG12903CB0BA7.mid',
#   'instrument_name': 6,
#   'key_signature': 1,
#   'note_on': 3836,
#   'pitchwheel': 20,
#   'program_change': 5,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'time_signature': 1,
#   'track_name': 6},
#  {'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRVUPKW128F4279DEA.mid',
#   'note_off': 529,
#   'note_on': 529,
#   'pitchwheel': 12,
#   'program_change': 12,
#   'set_tempo': 1},
#  {'channel_prefix': 14,
#   'control_change': 28,
#   'copyright': 1,
#   'end_of_track': 23,
#   'filename': 'data/lakh/lmd_subset/TRAFKWE128F42826AE.mid',
#   'key_signature': 1,
#   'midi_port': 22,
#   'note_off': 17081,
#   'note_on': 17081,
#   'program_change': 14,
#   'set_tempo': 1,
#   'text': 1,
#   'time_signature': 1,
#   'track_name': 23},
#  {'control_change': 288,
#   'end_of_track': 9,
#   'filename': 'data/lakh/lmd_subset/TRBVUWM12903CCEB50.mid',
#   'note_off': 614,
#   'note_on': 614,
#   'pitchwheel': 72,
#   'program_change': 48,
#   'set_tempo': 3,
#   'track_name': 8},
#  {'control_change': 352,
#   'end_of_track': 15,
#   'filename': 'data/lakh/lmd_subset/TRHIMXD128E0786BA8.mid',
#   'key_signature': 2,
#   'midi_port': 14,
#   'note_on': 22364,
#   'pitchwheel': 543,
#   'program_change': 14,
#   'set_tempo': 1,
#   'time_signature': 2,
#   'track_name': 7},
#  {'channel_prefix': 14,
#   'control_change': 1298,
#   'end_of_track': 17,
#   'filename': 'data/lakh/lmd_subset/TRAKXIR128F92CF85A.mid',
#   'note_on': 13100,
#   'pitchwheel': 204,
#   'program_change': 14,
#   'set_tempo': 1,
#   'text': 376,
#   'track_name': 2},
#  {'control_change': 872,
#   'end_of_track': 12,
#   'filename': 'data/lakh/lmd_subset/TRRPEDM128F4270FF0.mid',
#   'note_off': 5134,
#   'note_on': 5134,
#   'pitchwheel': 264,
#   'program_change': 14,
#   'set_tempo': 2,
#   'time_signature': 1,
#   'track_name': 11},
#  {'control_change': 879,
#   'copyright': 1,
#   'end_of_track': 14,
#   'filename': 'data/lakh/lmd_subset/TRGCFMF128F14557F4.mid',
#   'key_signature': 1,
#   'lyrics': 350,
#   'midi_port': 13,
#   'note_on': 16380,
#   'pitchwheel': 12,
#   'program_change': 34,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'text': 5,
#   'time_signature': 1,
#   'track_name': 15},
#  {'control_change': 944,
#   'end_of_track': 16,
#   'filename': 'data/lakh/lmd_subset/TRZVKAJ128F9320C03.mid',
#   'key_signature': 1,
#   'midi_port': 15,
#   'note_on': 5588,
#   'program_change': 12,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 15},
#  {'control_change': 90,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRIJKBS128F92F9DA8.mid',
#   'note_off': 966,
#   'note_on': 974,
#   'program_change': 8,
#   'set_tempo': 1,
#   'sysex': 1,
#   'time_signature': 1},
#  {'control_change': 2100,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRXOOOE128F931EB02.mid',
#   'key_signature': 1,
#   'marker': 111,
#   'note_on': 12198,
#   'program_change': 488,
#   'set_tempo': 1,
#   'sysex': 16,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 150,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRWAOZC12903CA07A4.mid',
#   'key_signature': 1,
#   'marker': 2,
#   'note_on': 3262,
#   'program_change': 2,
#   'set_tempo': 200,
#   'text': 9,
#   'time_signature': 1,
#   'track_name': 2},
#  {'channel_prefix': 15,
#   'control_change': 45,
#   'copyright': 1,
#   'end_of_track': 16,
#   'filename': 'data/lakh/lmd_subset/TRBISFE12903CB0541.mid',
#   'key_signature': 1,
#   'midi_port': 15,
#   'note_off': 7918,
#   'note_on': 7918,
#   'program_change': 19,
#   'set_tempo': 15,
#   'time_signature': 1,
#   'track_name': 6},
#  {'control_change': 1884,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRBAMLS128F92ED810.mid',
#   'note_off': 7701,
#   'note_on': 7701,
#   'pitchwheel': 54,
#   'program_change': 14,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'sysex': 222,
#   'text': 1,
#   'time_signature': 1},
# ...
#   'midi_port': 18,
#   'note_on': 17032,
#   'pitchwheel': 913,
#   'program_change': 13,
#   'set_tempo': 28,
#   'time_signature': 34,
#   'track_name': 18},
#  {'control_change': 306,
#   'end_of_track': 3,
#   'filename': 'data/lakh/lmd_subset/TRGZVTN12903D0C75A.mid',
#   'note_off': 1449,
#   'note_on': 1449,
#   'set_tempo': 1,
#   'sysex': 1,
#   'time_signature': 1,
#   'track_name': 2},
#  {'control_change': 554,
#   'end_of_track': 10,
#   'filename': 'data/lakh/lmd_subset/TRMRSOF12903CCF516.mid',
#   'key_signature': 5,
#   'marker': 2,
#   'midi_port': 9,
#   'note_on': 4296,
#   'pitchwheel': 99,
#   'program_change': 9,
#   'set_tempo': 99,
#   'time_signature': 5,
#   'track_name': 9},
#  {'control_change': 425,
#   'end_of_track': 5,
#   'filename': 'data/lakh/lmd_subset/TRSHGFQ12903CBA4EF.mid',
#   'key_signature': 1,
#   'midi_port': 4,
#   'note_on': 4202,
#   'program_change': 4,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'time_signature': 1,
#   'track_name': 4},
#  {'control_change': 107,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRMTMQN128E0784F69.mid',
#   'lyrics': 496,
#   'note_off': 2448,
#   'note_on': 2448,
#   'pitchwheel': 6,
#   'program_change': 6,
#   'set_tempo': 1,
#   'sysex': 5,
#   'text': 2},
#  {'control_change': 714,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRIKWER128F147D55B.mid',
#   'note_on': 7088,
#   'pitchwheel': 82,
#   'program_change': 70,
#   'set_tempo': 1,
#   'sysex': 28,
#   'text': 55,
#   'time_signature': 2,
#   'track_name': 1},
#  {'control_change': 151,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRKVFWW128F42376B5.mid',
#   'lyrics': 432,
#   'note_off': 518,
#   'note_on': 14318,
#   'pitchwheel': 14,
#   'program_change': 14,
#   'set_tempo': 2,
#   'sysex': 4,
#   'text': 14,
#   'time_signature': 1,
#   'track_name': 1},
#  {'channel_prefix': 11,
#   'control_change': 635,
#   'end_of_track': 17,
#   'filename': 'data/lakh/lmd_subset/TRKKFQT12903CEC41E.mid',
#   'key_signature': 1,
#   'midi_port': 16,
#   'note_off': 4458,
#   'note_on': 4458,
#   'pitchwheel': 459,
#   'program_change': 11,
#   'set_tempo': 2,
#   'smpte_offset': 1,
#   'time_signature': 1,
#   'track_name': 17},
#  {'aftertouch': 115,
#   'control_change': 2332,
#   'end_of_track': 13,
#   'filename': 'data/lakh/lmd_subset/TRIRHLP128F92CD4F8.mid',
#   'key_signature': 1,
#   'midi_port': 12,
#   'note_on': 14858,
#   'pitchwheel': 514,
#   'program_change': 11,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'time_signature': 1,
#   'track_name': 12},
#  {'control_change': 125,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRKHUVX128F42A3AD4.mid',
#   'lyrics': 613,
#   'note_off': 4,
#   'note_on': 13284,
#   'pitchwheel': 502,
#   'program_change': 10,
#   'set_tempo': 1,
#   'sysex': 5,
#   'text': 2},
#  {'channel_prefix': 11,
#   'control_change': 359,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRWWEVA128F14693E2.mid',
#   'lyrics': 331,
#   'note_on': 15572,
#   'pitchwheel': 71,
#   'program_change': 11,
#   'set_tempo': 1,
#   'sysex': 5,
#   'text': 14,
#   'time_signature': 1,
#   'track_name': 1},
#  {'channel_prefix': 8,
#   'control_change': 64,
#   'end_of_track': 10,
#   'filename': 'data/lakh/lmd_subset/TRBSPFF128E0780EAC.mid',
#   'note_off': 12294,
#   'note_on': 12294,
#   'program_change': 8,
#   'set_tempo': 2,
#   'sysex': 1,
#   'text': 11,
#   'time_signature': 1},
#  {'channel_prefix': 5,
#   'control_change': 5,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRGIJFK128F9329556.mid',
#   'instrument_name': 5,
#   'key_signature': 1,
#   'note_off': 857,
#   'note_on': 862,
#   'pitchwheel': 150,
#   'program_change': 5,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'sysex': 1,
#   'time_signature': 1},
#  {'control_change': 252,
#   'end_of_track': 5,
#   'filename': 'data/lakh/lmd_subset/TRJZWUU128F92EBBBE.mid',
#   'key_signature': 1,
#   'midi_port': 6,
#   'note_on': 1926,
#   'program_change': 2,
#   'set_tempo': 290,
#   'sysex': 1,
#   'time_signature': 5,
#   'track_name': 4},
#  {'control_change': 4168,
#   'end_of_track': 17,
#   'filename': 'data/lakh/lmd_subset/TRHBKBE128F42202A8.mid',
#   'note_on': 7814,
#   'pitchwheel': 960,
#   'program_change': 16,
#   'set_tempo': 1,
#   'text': 537,
#   'time_signature': 1,
#   'track_name': 3},
#  {'control_change': 314,
#   'end_of_track': 11,
#   'filename': 'data/lakh/lmd_subset/TRECRGP128F1470AC7.mid',
#   'marker': 15,
#   'note_off': 15031,
#   'note_on': 15031,
#   'pitchwheel': 3816,
#   'program_change': 15,
#   'set_tempo': 1,
#   'text': 643,
#   'time_signature': 1,
#   'track_name': 11},
#  {'channel_prefix': 11,
#   'control_change': 529,
#   'end_of_track': 19,
#   'filename': 'data/lakh/lmd_subset/TRYEPDD128F145E3B9.mid',
#   'key_signature': 1,
#   'midi_port': 18,
#   'note_off': 1161,
#   'note_on': 1161,
#   'program_change': 9,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 15},
#  {'control_change': 169,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRGISOX128F930924D.mid',
#   'note_on': 6906,
#   'pitchwheel': 57,
#   'program_change': 11,
#   'set_tempo': 8,
#   'sysex': 5,
#   'text': 1},
#  {'control_change': 249,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRBSSNO128F9346316.mid',
#   'lyrics': 409,
#   'note_off': 4,
#   'note_on': 8808,
#   'pitchwheel': 35,
#   'program_change': 10,
#   'set_tempo': 1,
#   'sysex': 5,
#   'text': 2},
#  {'control_change': 8,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRRGIBF128F427025E.mid',
#   'lyrics': 305,
#   'note_off': 3526,
#   'note_on': 3520,
#   'program_change': 7,
#   'set_tempo': 1,
#   'time_signature': 1},
#  {'control_change': 10,
#   'copyright': 1,
#   'end_of_track': 13,
#   'filename': 'data/lakh/lmd_subset/TRWQAFX128F428DBB0.mid',
#   'key_signature': 1,
#   'marker': 1,
#   'note_on': 9288,
#   'program_change': 9,
#   'set_tempo': 1,
#   'text': 581,
#   'time_signature': 1,
#   'track_name': 14},
#  {'control_change': 193,
#   'end_of_track': 14,
#   'filename': 'data/lakh/lmd_subset/TRGMFVG12903D11B88.mid',
#   'key_signature': 1,
#   'midi_port': 20,
#   'note_on': 18840,
#   'pitchwheel': 63,
#   'program_change': 12,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'sysex': 6,
#   'text': 15,
#   'time_signature': 1,
#   'track_name': 2},
#  {'control_change': 56,
#   'end_of_track': 10,
#   'filename': 'data/lakh/lmd_subset/TRJBVUR12903CEB188.mid',
#   'note_off': 7923,
#   'note_on': 7923,
#   'pitchwheel': 144,
#   'program_change': 8,
#   'set_tempo': 1,
#   'sysex': 3,
#   'time_signature': 1,
#   'track_name': 9},
#  {'control_change': 103,
#   'end_of_track': 10,
#   'filename': 'data/lakh/lmd_subset/TRUHXSV12903CFE3AC.mid',
#   'note_off': 4513,
#   'note_on': 4513,
#   'pitchwheel': 2397,
#   'program_change': 7,
#   'set_tempo': 1,
#   'sysex': 2,
#   'time_signature': 1,
#   'track_name': 9},
#  {'control_change': 54,
#   'end_of_track': 19,
#   'filename': 'data/lakh/lmd_subset/TROGCMF128F424113D.mid',
#   'key_signature': 1,
#   'midi_port': 18,
#   'note_on': 15382,
#   'polytouch': 4922,
#   'program_change': 12,
#   'sequencer_specific': 1,
#   'set_tempo': 2,
#   'time_signature': 1,
#   'track_name': 18},
#  {'control_change': 37,
#   'end_of_track': 7,
#   'filename': 'data/lakh/lmd_subset/TRBTFDC128F9316AF9.mid',
#   'key_signature': 1,
#   'marker': 1,
#   'midi_port': 6,
#   'note_on': 1802,
#   'program_change': 12,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 6},
#  {'control_change': 125,
#   'end_of_track': 8,
#   'filename': 'data/lakh/lmd_subset/TRXIHGI128EF35C422.mid',
#   'key_signature': 1,
#   'midi_port': 7,
#   'note_on': 4176,
#   'program_change': 4,
#   'sequencer_specific': 12,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'time_signature': 1,
#   'track_name': 8},
#  {'control_change': 16,
#   'end_of_track': 12,
#   'filename': 'data/lakh/lmd_subset/TRLNQTC128F9314188.mid',
#   'key_signature': 1,
#   'midi_port': 11,
#   'note_on': 4238,
#   'program_change': 8,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 11},
#  {'control_change': 126,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRTEIKZ12903CDD836.mid',
#   'note_on': 12102,
#   'pitchwheel': 9,
#   'program_change': 10,
#   'set_tempo': 1,
#   'sysex': 5,
#   'text': 1},
#  {'aftertouch': 1521,
#   'channel_prefix': 8,
#   'control_change': 252,
#   'end_of_track': 10,
#   'filename': 'data/lakh/lmd_subset/TRMIPJP128C71969AD.mid',
#   'note_on': 11036,
#   'pitchwheel': 308,
#   'program_change': 7,
#   'set_tempo': 1,
#   'sysex': 6,
#   'text': 19,
#   'time_signature': 1},
#  {'control_change': 1492,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRYGETI128F4293E71.mid',
#   'lyrics': 379,
#   'note_on': 13410,
#   'pitchwheel': 140,
#   'program_change': 12,
#   'set_tempo': 1,
#   'sysex': 5,
#   'text': 2},
#  {'control_change': 898,
#   'copyright': 1,
#   'end_of_track': 16,
#   'filename': 'data/lakh/lmd_subset/TREYHAT128F4247CEA.mid',
#   'key_signature': 1,
#   'marker': 18,
#   'note_on': 14038,
#   'program_change': 21,
#   'set_tempo': 1,
#   'sysex': 2,
#   'text': 3,
#   'time_signature': 1,
#   'track_name': 15},
#  {'aftertouch': 11,
#   'control_change': 4363,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRKZJVY128F92ED752.mid',
#   'key_signature': 1,
#   'lyrics': 267,
#   'marker': 4,
#   'note_off': 2860,
#   'note_on': 6864,
#   'pitchwheel': 3506,
#   'program_change': 11,
#   'set_tempo': 2,
#   'sysex': 4,
#   'time_signature': 1,
#   'track_name': 2},
#  {'control_change': 31,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRMFLQM12903CBABA6.mid',
#   'key_signature': 1,
#   'marker': 4,
#   'midi_port': 11,
#   'note_off': 879,
#   'note_on': 891,
#   'program_change': 9,
#   'set_tempo': 1,
#   'sysex': 1,
#   'text': 1,
#   'time_signature': 1,
#   'track_name': 1},
#  {'end_of_track': 8,
#   'filename': 'data/lakh/lmd_subset/TRJRUGZ128F42900BC.mid',
#   'note_off': 64,
#   'note_on': 2028,
#   'program_change': 7,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 8},
#  {'end_of_track': 4,
#   'filename': 'data/lakh/lmd_subset/TROEIGT12903C980C2.mid',
#   'note_off': 1452,
#   'note_on': 1452,
#   'program_change': 1,
#   'set_tempo': 9,
#   'time_signature': 1,
#   'track_name': 3},
#  {'control_change': 439,
#   'copyright': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TREENLS128F4268032.mid',
#   'lyrics': 523,
#   'note_off': 12245,
#   'note_on': 12245,
#   'pitchwheel': 54,
#   'program_change': 12,
#   'set_tempo': 1,
#   'sysex': 5,
#   'time_signature': 1},
#  {'control_change': 3,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRLODKW128F42A0EED.mid',
#   'note_off': 2508,
#   'note_on': 2508,
#   'program_change': 3,
#   'sequencer_specific': 1,
#   'set_tempo': 2,
#   'time_signature': 1},
#  {'aftertouch': 44,
#   'control_change': 2386,
#   'end_of_track': 16,
#   'filename': 'data/lakh/lmd_subset/TRROXZM128F92DF64E.mid',
#   'key_signature': 15,
#   'note_off': 6640,
#   'note_on': 6640,
#   'pitchwheel': 891,
#   'program_change': 13,
#   'sequencer_specific': 1,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 15},
#  {'control_change': 4417,
#   'end_of_track': 15,
#   'filename': 'data/lakh/lmd_subset/TRFKVLY128F4267883.mid',
#   'key_signature': 1,
#   'midi_port': 14,
#   'note_on': 3494,
#   'pitchwheel': 1,
#   'program_change': 10,
#   'set_tempo': 148,
#   'text': 96,
#   'time_signature': 1,
#   'track_name': 14},
#  {'channel_prefix': 8,
#   'control_change': 66,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRKPHPA128F92FC3E4.mid',
#   'key_signature': 1,
#   'midi_port': 8,
#   'note_on': 13024,
#   'pitchwheel': 135,
#   'program_change': 6,
#   'sequencer_specific': 26,
#   'set_tempo': 1,
#   'sysex': 11,
#   'time_signature': 2,
#   'track_name': 6},
#  {'control_change': 4174,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRYMLHU128F931E0AE.mid',
#   'key_signature': 1,
#   'lyrics': 347,
#   'midi_port': 7,
#   'note_on': 6534,
#   'pitchwheel': 141,
#   'program_change': 28,
#   'set_tempo': 12,
#   'smpte_offset': 1,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 78,
#   'end_of_track': 14,
#   'filename': 'data/lakh/lmd_subset/TRNWQBX12903CAD7C5.mid',
#   'key_signature': 1,
#   'marker': 3,
#   'midi_port': 17,
#   'note_on': 1956,
#   'program_change': 9,
#   'set_tempo': 1,
#   'sysex': 32,
#   'time_signature': 1,
#   'track_name': 13},
#  {'control_change': 945,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRHBQFD128F931E22E.mid',
#   'instrument_name': 1,
#   'key_signature': 1,
#   'note_off': 11175,
#   'note_on': 11175,
#   'pitchwheel': 782,
#   'program_change': 11,
#   'set_tempo': 1,
#   'smpte_offset': 1,
#   'sysex': 9,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 278,
#   'end_of_track': 16,
#   'filename': 'data/lakh/lmd_subset/TRUOGAU128E0780EFD.mid',
#   'key_signature': 15,
#   'note_off': 7498,
#   'note_on': 7498,
#   'program_change': 28,
#   'sequencer_specific': 1,
#   'set_tempo': 6,
#   'time_signature': 1,
#   'track_name': 10},
#  {'control_change': 217,
#   'end_of_track': 12,
#   'filename': 'data/lakh/lmd_subset/TRJQBVM128F9309BA1.mid',
#   'key_signature': 1,
#   'midi_port': 11,
#   'note_on': 6518,
#   'program_change': 7,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 12},
#  {'control_change': 8,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRCLNXW128F4238B01.mid',
#   'note_off': 683,
#   'note_on': 747,
#   'program_change': 4,
#   'sequencer_specific': 1,
#   'set_tempo': 1,
#   'sysex': 1,
#   'time_signature': 1},
#  {'control_change': 71,
#   'end_of_track': 11,
#   'filename': 'data/lakh/lmd_subset/TRAVKWA128F4271E63.mid',
#   'note_off': 7662,
#   'note_on': 7662,
#   'pitchwheel': 9599,
#   'program_change': 18,
#   'sequencer_specific': 1,
#   'set_tempo': 5,
#   'sysex': 1,
#   'text': 327,
#   'time_signature': 1,
#   'track_name': 3},
#  {'control_change': 90,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRPNQWQ128E0789A3F.mid',
#   'key_signature': 1,
#   'note_on': 19024,
#   'pitchwheel': 274,
#   'program_change': 10,
#   'set_tempo': 1,
#   'text': 1,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 13,
#   'end_of_track': 13,
#   'filename': 'data/lakh/lmd_subset/TREGUNS12903CCCF32.mid',
#   'note_off': 4953,
#   'note_on': 4953,
#   'program_change': 8,
#   'set_tempo': 1,
#   'sysex': 1,
#   'text': 12,
#   'time_signature': 1},
#  {'control_change': 1,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRUJIUQ12903CE0975.mid',
#   'note_on': 1206,
#   'program_change': 22,
#   'set_tempo': 1,
#   'text': 1},
#  {'end_of_track': 7,
#   'filename': 'data/lakh/lmd_subset/TRCKFYF12903CBD8F3.mid',
#   'note_on': 11800,
#   'program_change': 6,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 6},
#  {'control_change': 407,
#   'end_of_track': 10,
#   'filename': 'data/lakh/lmd_subset/TRNPRZM128F92CB70A.mid',
#   'key_signature': 1,
#   'midi_port': 9,
#   'note_on': 25558,
#   'program_change': 6,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 9},
#  {'aftertouch': 648,
#   'control_change': 1157,
#   'end_of_track': 10,
#   'filename': 'data/lakh/lmd_subset/TRHERAB128F42BC659.mid',
#   'key_signature': 1,
#   'note_off': 2926,
#   'note_on': 2926,
#   'pitchwheel': 532,
#   'program_change': 8,
#   'set_tempo': 1,
#   'sysex': 1,
#   'time_signature': 1,
#   'track_name': 8},
#  {'control_change': 32,
#   'end_of_track': 1,
#   'filename': 'data/lakh/lmd_subset/TRIZHSW128F425A1EC.mid',
#   'key_signature': 1,
#   'marker': 4,
#   'midi_port': 2,
#   'note_on': 10522,
#   'pitchwheel': 66,
#   'program_change': 8,
#   'set_tempo': 1,
#   'sysex': 6,
#   'time_signature': 1,
#   'track_name': 1},
#  {'control_change': 5,
#   'end_of_track': 7,
#   'filename': 'data/lakh/lmd_subset/TRRUNLM128F931C29F.mid',
#   'key_signature': 1,
#   'midi_port': 6,
#   'note_on': 1004,
#   'program_change': 6,
#   'set_tempo': 39,
#   'time_signature': 18,
#   'track_name': 6},
#  {'control_change': 957,
#   'end_of_track': 10,
#   'filename': 'data/lakh/lmd_subset/TRETFEM128F1493294.mid',
#   'key_signature': 1,
#   'midi_port': 11,
#   'note_on': 7478,
#   'program_change': 9,
#   'set_tempo': 2,
#   'sysex': 1,
#   'text': 4,
#   'time_signature': 1,
#   'track_name': 10},
#  {'control_change': 831,
#   'end_of_track': 17,
#   'filename': 'data/lakh/lmd_subset/TRHVZYA128E07848F1.mid',
#   'note_on': 8982,
#   'pitchwheel': 473,
#   'set_tempo': 1,
#   'time_signature': 1,
#   'track_name': 14},
#  {'control_change': 1128,
#   'end_of_track': 16,
#   'filename': 'data/lakh/lmd_subset/TREZCTL128F92EB17D.mid',
#   'key_signature': 1,
#   'midi_port': 17,
#   'note_on': 16842,
#   'pitchwheel': 4,
#   'program_change': 13,
#   'set_tempo': 2,
#   'sysex': 1,
#   'text': 469,
#   'time_signature': 1,
#   'track_name': 2},
#  ...]

# %%
import sys
# !{sys.executable} -m pip install matplotlib
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(d)
df

# df.plot.hist(grid=True, bins=20, rwidth=0.9,
#                    color='#607c8e')
df.plot.hist(grid=True)
plt.title('Events per type of event, all datasets')
plt.xlabel('Event type')
plt.ylabel('Counts')
plt.grid(axis='y', alpha=0.75)

# %%
# Cleaning data frame

def label_dataset(row):
    if 'slac' in row['filename']:
        return 'SLAC'
    if 'musedata' in row['filename']:
        return 'MuseData'
    if 'lakh' in row['filename']:
        return 'Lakh'
    return 'Other'

df.apply(lambda row: label_dataset(row), axis=1)

df_clean = df[['program_change', 'note_on']]
df_clean['dataset'] = df.apply(lambda row: label_dataset(row), axis=1)

df_clean[df_clean['dataset'] == 'MuseData']
# print(df_clean.loc[df_clean['dataset'] == 'Lakh'])
# print(max(df_clean['note_on']))
# print(max(df_clean['program_change']))

# plt.title('Events per type of event, all datasets')
# plt.xlabel('Event type')
# plt.ylabel('Counts')
# plt.grid(axis='y', alpha=0.75)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#        program_change  note_on   dataset
# 30732            38.0    17218  MuseData
# 30733            12.0    18700  MuseData
# 30734            28.0    21070  MuseData
# 30735            26.0     8850  MuseData
# 30736             6.0      807  MuseData
# 30737             4.0      896  MuseData
# 30738             1.0     1276  MuseData
# 30739             2.0     1200  MuseData
# 30740             3.0      120  MuseData
# 30741             3.0      120  MuseData
# 30742            15.0    14491  MuseData
# 30743             6.0     2501  MuseData
# 30744            10.0    16656  MuseData
# 30745            10.0    34368  MuseData
# 30746            10.0    26860  MuseData
# 30747            10.0     9104  MuseData
# 30748             5.0      978  MuseData
# 30749             6.0     1245  MuseData
# 30750             3.0     1630  MuseData
# 30751             1.0     1116  MuseData
# 30752             9.0     2202  MuseData
# 30753             9.0     9037  MuseData
# 30754             9.0     6131  MuseData
# 30755             4.0      864  MuseData
# 30756             5.0     1322  MuseData
# 30757             5.0      757  MuseData
# 30758             3.0      106  MuseData
# 30759             6.0     1925  MuseData
# 30760             4.0     1984  MuseData
# 30761            11.0      489  MuseData
# ...               ...      ...       ...
# 31045            53.0    15390  MuseData
# 31046            47.0    80638  MuseData
# 31047            21.0    22388  MuseData
# 31048             3.0      859  MuseData
# 31049             5.0      439  MuseData
# 31050            26.0     4332  MuseData
# 31051            56.0    37424  MuseData
# 31052             4.0     1456  MuseData
# 31053             3.0      805  MuseData
# 31054             3.0     1081  MuseData
# 31055             5.0      754  MuseData
# 31056             5.0      782  MuseData
# 31057             3.0      179  MuseData
# 31058            11.0     6592  MuseData
# 31059             4.0     2297  MuseData
# 31060             3.0      198  MuseData
# 31061             1.0     1802  MuseData
# 31062             7.0    11940  MuseData
# 31063            11.0    20222  MuseData
# 31064            12.0    22240  MuseData
# 31065             9.0     5304  MuseData
# 31066             4.0      804  MuseData
# 31067             4.0      612  MuseData
# 31068             4.0     1665  MuseData
# 31069             6.0      559  MuseData
# 31070            28.0    12892  MuseData
# 31071            18.0    23044  MuseData
# 31072            11.0    15960  MuseData
# 31073             2.0     1270  MuseData
# 31074             2.0     1270  MuseData
#
# [343 rows x 3 columns]

# %%
# Plots

# All dataset
df_clean.hist(grid=True, bins=200)

# Lakh
df_clean.loc[df_clean['dataset'] == 'Lakh'].hist(grid=True, bins=200)

# SLAC
df_clean.loc[df_clean['dataset'] == 'SLAC'].hist(grid=True, bins=200)

# MuseData
df_clean.loc[df_clean['dataset'] == 'MuseData'].hist(grid=True, bins=200)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11076f810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1107a5990>]], dtype=object)

# %%
df = pd.DataFrame({
'length': [1.5, 0.5, 1.2, 0.9, 3],
'width': [0.7, 0.2, 0.15, 0.2, 1.1]
}, index=['pig', 'rabbit', 'duck', 'chicken', 'horse'])
df
# Out:
#          length  width
# pig         1.5   0.70
# rabbit      0.5   0.20
# duck        1.2   0.15
# chicken     0.9   0.20
# horse       3.0   1.10

# %%
hist = df.hist(bins=3)
